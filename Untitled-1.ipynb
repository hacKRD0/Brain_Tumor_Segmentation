# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# plt.figure()
a = [i/10 for i in range(1,101,6)]
b = 1/np.exp(a) + np.array(a)**2/1000
a = np.array(a)*10
b = np.array(b)/100
plt.plot(a,b)
plt.xlabel("Number of Threads")
plt.ylabel("Time Taken")
plt.show()
